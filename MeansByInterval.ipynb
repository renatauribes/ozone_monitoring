# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hours = pd.read_csv("/content/group_hour.csv")
days = pd.read_csv("/content/group_day.csv")
months = pd.read_csv("/content/group_month.csv")

# %%
hours.index = [*range(1, 25)]
hours.head()
# Out:
#           O3       PM10      PM2.5  ...         PRS         WS     RAINF
# 1  22.333610  44.589262  17.274871  ...  727.133381  13.438459  0.013053
# 2  21.991365  42.443602  16.917678  ...  727.149322  12.429562  0.009271
# 3  21.510844  38.322921  16.511326  ...  727.037335  11.227411  0.009506
# 4  20.534905  38.434897  16.534962  ...  726.902392  10.005825  0.009128
# 5  19.094288  37.875115  16.540803  ...  726.810438   9.017756  0.008825
#
# [5 rows x 10 columns]

# %%
hours.plot.line(subplots=True, figsize=(16, 12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5687e9efd0>,
# ...
#       dtype=object)

# %%
days.index = [*range(1, 32)]
days.tail()
# Out:
#            O3       PM10      PM2.5  ...         PRS         WS     RAINF
# 27  27.559337  52.868116  19.619559  ...  726.558454  12.586218  0.136552
# 28  27.348493  53.536633  19.947233  ...  726.522549  12.372572  0.134558
# 29  27.984096  47.432454  17.328321  ...  727.520500  12.197307  0.135013
# 30  28.295237  49.352168  18.481232  ...  727.521467  12.102717  0.135140
# 31  25.927339  52.796315  19.883531  ...  727.503266  11.806153  0.130541
#
# [5 rows x 10 columns]

# %%
days.plot.line(subplots=True, figsize=(16, 12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5686a1f490>,
# ...
#       dtype=object)

# %%
months.index = [*range(1, 13)]
months.head()
# Out:
#           O3       PM10      PM2.5  ...         PRS         WS     RAINF
# 1  21.901754  54.653275  21.919615  ...  729.372784  10.107775  0.096565
# 2  23.465097  60.391688  21.299526  ...  727.740125  11.432483  0.109254
# 3  31.935944  59.052968  19.516227  ...  727.251490  13.538265  0.130336
# 4  35.753242  52.579801  18.384091  ...  724.417893  13.026060  0.145941
# 5  33.941961  43.596659  17.968884  ...  724.763716  14.002258  0.153520
#
# [5 rows x 10 columns]

# %%
months.plot.line(subplots=True, figsize=(16, 12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5684de8310>,
# ...
#       dtype=object)
